# %%
#Work as SQL
import pandas as pd
import sqlite3

# %%
#read the CSV
df = pd.read_csv('./data/casoscovid19.csv')
#connect to a database
conn = sqlite3.connect("casoscovid19.db") #if the db does not exist, this creates a Any_Database_Name.db file in the current directory
#store your table in the database:
df.to_sql('test_0', conn)

# %%
#connect to a database
conn = sqlite3.connect("casoscovid19.db") 
#if the db does not exist, this creates a Any_Database_Name.db file in the current directory

# %%
#read a SQL Query out of your database and into a pandas dataframe
sql_string = 'SELECT * FROM test_0'
sql_string = 'SELECT COUNT(*) FROM test_0 WHERE clasificacion LIKE "%Caso confirmado%";'
gg = pd.read_sql(sql_string, conn)
gg
# Out:
#    COUNT(*)
# 0    216752

# %%
#read a SQL Query out of your database and into a pandas dataframe
sql_string = 'SELECT * FROM test_0 LIMIT 5;'
gg = pd.read_sql(sql_string, conn)
gg
# Out:
#    index  id_evento_caso sexo  edad edad_años_meses residencia_pais_nombre  \
# 0      0         1000000    M  53.0            Años              Argentina
# 1      1         1000002    M  21.0            Años              Argentina
# 2      2         1000003    F  40.0            Años              Argentina
# 3      3         1000005    F  58.0            Años              Argentina
# 4      4         1000006    M  28.0            Años              Argentina
#
#   residencia_provincia_nombre residencia_departamento_nombre  \
# 0                        CABA                SIN ESPECIFICAR
# 1                Buenos Aires                     La Matanza
# 2                     Córdoba                        Capital
# 3                     Mendoza                      Las Heras
# 4                Buenos Aires            Malvinas Argentinas
#
#   carga_provincia_nombre fecha_inicio_sintomas  ... fecha_fallecimiento  \
# 0           Buenos Aires                  None  ...                None
# 1           Buenos Aires                  None  ...                None
# 2                Córdoba            2020-05-24  ...                None
# 3                Mendoza                  None  ...                None
# 4           Buenos Aires            2020-05-30  ...                None
#
#    asistencia_respiratoria_mecanica carga_provincia_id origen_financiamiento  \
# 0                                NO                  6               Privado
# 1                                NO                  6               Público
# 2                                NO                 14               Privado
# 3                                NO                 50               Público
# 4                                NO                  6               Público
#
#                                  clasificacion clasificacion_resumen  \
# 0                              Caso Descartado            Descartado
# 1                              Caso Descartado            Descartado
# 2                              Caso Descartado            Descartado
# 3                              Caso Descartado            Descartado
# 4  Caso sospechoso - Con muestra sin resultado            Sospechoso
#
#   residencia_provincia_id fecha_diagnostico  residencia_departamento_id  \
# 0                       2        2020-06-09                           0
# 1                       6        2020-06-01                         427
# 2                      14        2020-06-01                          14
# 3                      50        2020-06-01                          49
# 4                       6              None                         515
#
#   ultima_actualizacion
# 0           2020-08-05
# 1           2020-08-05
# 2           2020-08-05
# 3           2020-08-05
# 4           2020-08-05
#
# [5 rows x 26 columns]

# %%
ultima_actualizacion

# %%
sql_string = 'SELECT DISTINCT residencia_departamento_nombre FROM test_0 WHERE residencia_provincia_nombre="Buenos Aires";'
gg = pd.read_sql(sql_string, conn)
gg
# Out:
#     residencia_departamento_nombre
# 0                       La Matanza
# 1              Malvinas Argentinas
# 2               Esteban Echeverría
# 3                            Tigre
# 4                  Tres de Febrero
# ..                             ...
# 131                       Tapalqué
# 132                     Pellegrini
# 133                  General Guido
# 134                       Tordillo
# 135                        Capital
#
# [136 rows x 1 columns]

# %%
sql_string = 'SELECT DISTINCT residencia_departamento_nombre FROM test_0 WHERE residencia_provincia_nombre="Buenos Aires";'
sql_string = 'select residencia_departamento_nombre, count(*) from test_0 WHERE residencia_provincia_nombre="Buenos Aires" AND clasificacion_resumen="Confirmado" group by residencia_departamento_nombre;'
gg = pd.read_sql(sql_string, conn)
gg
# Out:
#     residencia_departamento_nombre  count(*)
# 0                       25 de Mayo        34
# 1                       9 de Julio        21
# 2                    Adolfo Alsina         3
# 3           Adolfo Gonzales Chaves         1
# 4                          Alberti        20
# ..                             ...       ...
# 125                Tres de Febrero      4885
# 126                  Vicente López      2236
# 127                   Villa Gesell         9
# 128                      Villarino        19
# 129                         Zárate       460
#
# [130 rows x 2 columns]

# %%
sql_string = 'SELECT DISTINCT residencia_departamento_nombre FROM test_0 WHERE residencia_provincia_nombre="Buenos Aires";'
gg = pd.read_sql(sql_string, conn)
gg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-0294fcfb2da0> in <module>
#       1 sql_string = 'SELECT DISTINCT residencia_departamento_nombre FROM test_0 WHERE residencia_provincia_nombre="Buenos Aires";'
# ----> 2 gg = pd.read_sql(sql_string, conn)
#       3 gg
#
# NameError: name 'pd' is not defined

# %%
sql_string = 'select residencia_departamento_nombre, count(*) from test_0 WHERE residencia_provincia_nombre="Buenos Aires" group by residencia_departamento_nombre;'
gg = pd.read_sql(sql_string, conn)
gg
# Out:
#     residencia_departamento_nombre  count(*)
# 0                       25 de Mayo        34
# 1                       9 de Julio        21
# 2                    Adolfo Alsina         3
# 3           Adolfo Gonzales Chaves         1
# 4                          Alberti        20
# ..                             ...       ...
# 125                Tres de Febrero      4885
# 126                  Vicente López      2236
# 127                   Villa Gesell         9
# 128                      Villarino        19
# 129                         Zárate       460
#
# [130 rows x 2 columns]

# %%
sql_string = 'SELECT residencia_departamento_nombre, count(*) FROM test_0 WHERE (residencia_provincia_nombre="Buenos Aires"  AND clasificacion_resumen="Confirmado") group by residencia_departamento_nombre;'
gg = pd.read_sql(sql_string, conn)
gg
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# c:\python38\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1585         try:
# -> 1586             cur.execute(*args, **kwargs)
#    1587             return cur
#
# OperationalError: no such table: test_0
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-13-7599959e7ac1> in <module>
#       1 sql_string = 'SELECT residencia_departamento_nombre, count(*) FROM test_0 WHERE (residencia_provincia_nombre="Buenos Aires"  AND clasificacion_resumen="Confirmado") group by residencia_departamento_nombre;'
# ----> 2 gg = pd.read_sql(sql_string, conn)
#       3 gg
#
# c:\python38\lib\site-packages\pandas\io\sql.py in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize)
#     404
#     405     if isinstance(pandas_sql, SQLiteDatabase):
# --> 406         return pandas_sql.read_query(
#     407             sql,
#     408             index_col=index_col,
#
# c:\python38\lib\site-packages\pandas\io\sql.py in read_query(self, sql, index_col, coerce_float, params, parse_dates, chunksize)
#    1631
#    1632         args = _convert_params(sql, params)
# -> 1633         cursor = self.execute(*args)
#    1634         columns = [col_desc[0] for col_desc in cursor.description]
#    1635
#
# c:\python38\lib\site-packages\pandas\io\sql.py in execute(self, *args, **kwargs)
#    1596
#    1597             ex = DatabaseError(f"Execution failed on sql '{args[0]}': {exc}")
# -> 1598             raise ex from exc
#    1599
#    1600     @staticmethod
#
# DatabaseError: Execution failed on sql 'SELECT residencia_departamento_nombre, count(*) FROM test_0 WHERE (residencia_provincia_nombre="Buenos Aires"  AND clasificacion_resumen="Confirmado") group by residencia_departamento_nombre;': no such table: test_0

# %%
sql_string = 'SELECT residencia_provincia_nombre, count(*) FROM test_0 WHERE (clasificacion_resumen="Confirmado") group by residencia_provincia_nombre;'
#sql_string = 'SELECT carga_provincia_nombre, count(*) FROM test_0 WHERE (clasificacion_resumen="Confirmado") group by carga_provincia_nombre;'
gg = pd.read_sql(sql_string, conn)
gg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-628a55957256> in <module>
#       1 sql_string = 'SELECT residencia_provincia_nombre, count(*) FROM test_0 WHERE (clasificacion_resumen="Confirmado") group by residencia_provincia_nombre;'
#       2 #sql_string = 'SELECT carga_provincia_nombre, count(*) FROM test_0 WHERE (clasificacion_resumen="Confirmado") group by carga_provincia_nombre;'
# ----> 3 gg = pd.read_sql(sql_string, conn)
#       4 gg
#
# NameError: name 'pd' is not defined

# %%
sql_string = 'SELECT count(*) FROM test_0 WHERE (clasificacion_resumen="Confirmado");'
gg = pd.read_sql(sql_string, conn)
gg
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-2e9ac9411371> in <module>
#       1 sql_string = 'SELECT count(*) FROM test_0 WHERE (clasificacion_resumen="Confirmado");'
# ----> 2 gg = pd.read_sql(sql_string, conn)
#       3 gg
#
# NameError: name 'pd' is not defined

# %%
sql_string = 'SELECT DISTINCT residencia_departamento_nombre FROM test_0 WHERE residencia_provincia_nombre="Buenos Aires";'
sql_string = 'select residencia_departamento_nombre, count(*) from test_0 WHERE (clasificacion_resumen="Confirmado" AND residencia_provincia_nombre="Buenos Aires") group by residencia_departamento_nombre;'
gg = pd.read_sql(sql_string, conn)
gg
# Out:
#     residencia_departamento_nombre  count(*)
# 0                       25 de Mayo        34
# 1                       9 de Julio        21
# 2                    Adolfo Alsina         3
# 3           Adolfo Gonzales Chaves         1
# 4                          Alberti        20
# ..                             ...       ...
# 125                Tres de Febrero      4885
# 126                  Vicente López      2236
# 127                   Villa Gesell         9
# 128                      Villarino        19
# 129                         Zárate       460
#
# [130 rows x 2 columns]
